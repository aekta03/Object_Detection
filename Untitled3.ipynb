# %% [markdown]
# <a href="https://colab.research.google.com/github/aekta03/Object_Detection/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/AIAnytime/Llama-3-ORPO-Fine-Tuning.git

# %%
# !pip install -U transformers datasets accelerate peft trl bitsandbytes wandb

# %%
import gc
import os
import torch
import wandb

from datasets import load_dataset
from google.colab import userdata
from peft import LoraConfig, PeftModel, prepare_model_for_kbit_training
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    TrainingArguments,
    pipeline
)
from trl import ORPOConfig, ORPOTrainer, setup_chat_format

# The 'BB-FT', 'Comment S', 'D' lines were removed as they were invalid.

# %%
import torch

# Check CUDA device capability
if torch.cuda.is_available() and torch.cuda.get_device_capability()[0] >= 8:
    # Install flash-attn if the CUDA capability is sufficient
    # !pip install -qqq flash-attn
    attn_implementation = "flash_attention_2"
    torch_dtype = torch.bfloat16
else:
    attn_implementation = "eager"
    torch_dtype = torch.float16

print(f"Attention implementation: {attn_implementation}")
print(f"Torch data type: {torch_dtype}")

# %%
from huggingface_hub import notebook_login

# Log in to Hugging Face Hub
notebook_login()

# %%
import torch
from huggingface_hub import notebook_login
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
from peft import LoraConfig, prepare_model_for_kbit_training
from trl import setup_chat_format

# Step 1: Log in to Hugging Face
notebook_login()

# Model details
base_model = "meta-llama/Meta-Llama-3-8B1"  # Ensure the model exists in Hugging Face Hub
new_model = "OrpoLlama3-8B-FT"

# QLORA config
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16,  # Assuming torch_dtype is torch.float16
    bnb_4bit_use_double_quant=True,
)

# LORA config
peft_config = LoraConfig(
    r=16,
    lora_alpha=32,
    lora_dropout=0.05,
    bias="none",
    task_type="CAUSAL_LM",  # Fixed task type syntax
    target_modules=['up_proj', 'down_proj', 'gate_proj', 'k_proj', 'q_proj', 'v_proj', 'o_proj']  # Corrected module names
)

# Step 2: Load the model and tokenizer with authentication token
# Replace '

# %%
# Install the datasets library if not already installed
# !pip install datasets

# Import the load_dataset function
from datasets import load_dataset

# Load the dataset with train and test splits
dataset = load_dataset(
    "HuggingFaceH4/ultrafeedback_binarized",
    split=["train_prefs", "test_prefs"]
)

# Access train and test data separately
train_data = dataset[0]  # 'train_prefs' split
test_data = dataset[1]   # 'test_prefs' split

# Display the first few examples from the training set
print(train_data[0])

# %%
dataset
# Out:
# [Dataset({
#      features: ['prompt', 'prompt_id', 'chosen', 'rejected', 'messages', 'score_chosen', 'score_rejected'],
#      num_rows: 61135
#  }),
#  Dataset({
#      features: ['prompt', 'prompt_id', 'chosen', 'rejected', 'messages', 'score_chosen', 'score_rejected'],
#      num_rows: 2000
#  })]

# %%
from datasets import load_dataset

# Load the dataset
dataset = load_dataset("HuggingFaceH4/ultrafeedback_binarized", split=["train_prefs", "test_prefs"])

# Define training and testing sample sizes
train_samples = 5000
original_train_samples = 61135

# Calculate the number of test samples based on the new training sample size
test_samples = int((2000 / original_train_samples) * train_samples)

# Shuffle and select a subset from both train and test sets
train_subset = dataset[0].shuffle(seed=42).select(range(train_samples))
test_subset = dataset[1].shuffle(seed=42).select(range(test_samples))

# Print the resulting subsets
print(train_subset)
print(test_subset)

# %%
import multiprocessing

# %%
from huggingface_hub import notebook_login

# %%
# This will prompt you to enter your token
notebook_login()

# Alternatively, you can hardcode the token (not recommended for security reasons)
# hf_token = "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"
# notebook_login(token=hf_token)

# %%
def process(row):
    # Apply tokenizer's chat template to both 'chosen' and 'rejected'
    #row["chosen"] = tokenizer.apply_chat_template(row["chosen"], tokenize=False)
    #row["rejected"] = tokenizer.apply_chat_template(row["rejected"], tokenize=False)
    return row

# Apply the process function to the training subset
dataset[0] = train_subset.map(
    process,
    num_proc=multiprocessing.cpu_count(),  # Use all available CPUs
    load_from_cache_file=False,
)

# Apply the process function to the testing subset
dataset[1] = test_subset.map(
    process,
    num_proc=multiprocessing.cpu_count(),  # Use all available CPUs
    load_from_cache_file=False,
)

# Print the processed datasets
print(dataset)
# Out:
# ...
# Map (num_proc=2):   0%|          | 0/163 [00:00<?, ? examples/s]

# %%
orpo_args = ORPOConfig(
    learning_rate=8e-6,
    beta=0.1,
    lr_scheduler_type="linear",
    max_length=1024,
    max_prompt_length=512,
    per_device_train_batch_size=2,
    per_device_eval_batch_size=2,
    gradient_accumulation_steps=4,
    optim="paged_adamw_8bit",
    max_steps=1000,
    evaluation_strategy="steps",
    eval_steps=0.2,
    logging_steps=1,
    warmup_steps=10,
    report_to="wandb",
    output_dir="./results/",
)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1545: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(

# %%
# !pip install transformers
